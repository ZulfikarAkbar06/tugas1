# %% [markdown]
# Tugas 1

# %%
print('Nama         :Zulfikar Akbar')
print('NPM          :2440406055')
print('Alamat       :Desa Marga Manunggal Jaya Rt 09. Jalur 3b')
print('Tinggi Badan :170 cm')
print('Berat Badan  :66,4 kg' )
# Out:
# Nama         :Zulfikar Akbar
# 'Berat Badan  :66,4 kg'

# %% [markdown]
# Tugas 2

# %%
print('\033[1m' + 'UNIVERSITAS TIDAR' + '\033[0m')
print("Universitas Tidar merupakan Perguruan Tinggi Pemerintah atau Perguruan Tinggi Negri yang telah ditetapkan berdasarkan peratuan Presiden Republik Indonesia Nomor 23 Tahun 2014 pada tanggal 1 April 2014")
print('')
print('\033[1m' + 'JURUSAN TEKNIK ELEKTRO, MEKATRONIKA, INFORMASI' + '\033[0m')
print('Jurusan Teknik Elektro, Mekatronika, Informasi terdiri atas tiga program studi, antara lain:')
print('   1. S1 Teknik Elektro \x1b[3m(Bachelor of Electrical Engineering)\x1b[0m ')
print('   2. S1 Teknik Mekatronika \x1b[3m(Bachelor of Mechatronics Engineering)\x1b[0m')
print('   3. S1 Teknologi Informasi \x1b[3m(Bachelor of Information Technology)\x1b[0m')
# Out:
# UNIVERSITAS TIDAR
# Universitas Tidar merupakan Perguruan Tinggi Pemerintah atau Perguruan Tinggi Negri yang telah ditetapkan berdasarkan peratuan Presiden Republik Indonesia Nomor 23 Tahun 2014 pada tanggal 1 April 2014
#
# JURUSAN TEKNIK ELEKTRO, MEKATRONIKA, INFORMASI
# Jurusan Teknik Elektro, Mekatronika, Informasi terdiri atas tiga program studi, antara lain:
#    1. S1 Teknik Elektro (Bachelor of Electrical Engineering)
#    2. S1 Teknik Mekatronika (Bachelor of Mechatronics Engineering)
#    3. S1 Teknologi Informasi (Bachelor of Information Technology)
