# %%
panjang = 20.5
lebar = 25
tinggi = 10

keliling = 2 * (panjang + lebar)
luas = panjang * lebar
volume = panjang * lebar * tinggi

print("Panjang = ",panjang)
print("Lebar = ",lebar)
print("Tinggi = ",tinggi)
print("Keliling = ",keliling)
print("Volume = ",volume)
# Out:
# Panjang =  20.5
# Lebar =  25
# Tinggi =  10
# Keliling =  91.0
# Volume =  5125.0

# %%
#soal nomor satu
agustus = 31
hari_masuk = agustus - 3
gaji_perjam = 30.000
jam_kerja = 8
total_gaji = ( hari_masuk * jam_kerja) * gaji_perjam
print ('Gaji dwi bulan agustus adalah Rp.',total_gaji)

#soal nomor 2
persen = 10/100
besar_persen = ( agustus * gaji_perjam) *persen
besar_tunjangan = total_gaji + besar_persen
print('gaji akhir dwi setelah dapet tunjangan adalah',besar_tunjangan)

#soal nomor 3
lembur = 5 * 10.000
print('gaji dwi setelah mendaptkan lembur adalah',besar_tunjangan+total_gaji)
# Out:
# Gaji dwi bulan agustus adalah Rp. 6720.0
# gaji akhir pak dwi setelah dapet tunjangan adalah 6813.0
# gaji setelah mendaptkan lembur adalah 13533.0

# %%
NilairatarataShafira = ((75 + 85)/2)
print(NilairatarataShafira)

JumlahNilaiHanifdanAndi = ((75 + 90 + 70 + 75))
print(JumlahNilaiHanifdanAndi)

NilairatarataWidya = ((85 + 85)/2)
NilairatarataDhanar = ((85 + 85)/2)
NilairatarataHikma = ((80 + 75)/2)
NilairatarataNedia = ((95 + 80)/2)
print(NilairatarataWidya)
print(NilairatarataDhanar)
print(NilairatarataHikma)
print(NilairatarataNedia)

rataratanilaimatakuliahKalkulus1 = ((85 + 80 + 75 + 95 + 85 + 75 + 70 + 85 + 80)/9)
print(rataratanilaimatakuliahKalkulus1)

rataratanilaimatakuliahmetodestatistika = ((75 + 90 + 80 + 80 + 85 + 90 + 75 + 85 + 75)/9)
print(rataratanilaimatakuliahmetodestatistika)
# Out:
# 80.0
# 310
# 85.0
# 85.0
# 77.5
# 87.5
# 81.11111111111111
# 81.66666666666667
